# %% [markdown]
# # Advanced Models Comparison (incuding XGboost and ANN)

# %% [markdown]
# | Model                               | Features Used                                                    | RMSE      | R²        | Notes                                                                                              |
# | ----------------------------------- | ---------------------------------------------------------------- | --------- | --------- | -------------------------------------------------------------------------------------------------- |
# | Ridge Regression (All feats)        | All (≈551 after OHE)                                             | 8.221     | 0.566     | Baseline linear model with L2 regularization, stable in high dimetional data                            |
# | Decision Tree (Tuned)               | max\_depth=10, min\_leaf=5                                       | 8.612     | 0.523     | Simple nonlinear model, improved with depth & leaf tuning                                          |
# | Random Forest (Tuned)               | n\_estimators=300, max\_depth=12, min\_leaf=5, max\_features=0.5 | 8.056     | 0.583     | Strong ensemble, captures nonlinear interactions well                                              |
# | **XGBoost (Tuned + EarlyStopping)** | RandomizedSearchCV tuned params, 5-fold CV                       | **7.984** | **0.590** | Best performer so far; gradient boosting handles OHE features well, regularization reduces overfit |
# | ANN (Keras DNN, Tuned)              | 2 hidden layers (128+64 units, Dropout, L2)                      | 9.848     | 0.377     | Underperformed vs tree models; likely needs more tuning, more features, or deeper architecture     |

# %% [markdown]
# **Best so far: XGBoost (Tuned + EarlyStopping) with RMSE ≈ 7.98, R² ≈ 0.59**
#
# - Random Forest (Tuned) remains very competitive (while including non-linear interactions)
#
# - Ridge Regression is a solid linear baseline
#
# - ANN Regressor (Keras DNN - deep neural network) underfits this dataset: may need more complex architecture or feature engineering .
